# %% [markdown]
# # JD-MOPPR (Taobao-style) on JD Search — Colab Notebook
#
# End-to-end ETL + two-tower + multi-objective softmax (exposure, click, cart, purchase) training.
#
# **Steps**: install deps → set Kaggle creds → run trainer.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip -q install --upgrade pip
# !pip -q install -r "/content/drive/MyDrive/Colab Notebooks/Repositories/jd_moppr/requirements.txt"

# %%
import os, sys, platform
print(platform.python_version())
sys.path += ['/content/drive/MyDrive/Colab Notebooks/Repositories/jd_moppr',
             '/content/drive/MyDrive/Colab Notebooks/Repositories/jd_moppr/src',
             '/content/drive/MyDrive/Colab Notebooks/Repositories/jd_moppr/src/jd_moppr']
print('Paths set.')
# Out:
# 3.12.11
# Paths set.

# %%
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/Colab Notebooks/Repositories/jd_moppr', '/content/drive/MyDrive/Colab Notebooks/Repositories/jd_moppr/src', '/content/drive/MyDrive/Colab Notebooks/Repositories/jd_moppr/src/jd_moppr']

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# /usr/local/lib/python3.12/dist-packages/Cryptodome/SelfTest/PublicKey/test_ECC_NIST.py:779: UserWarning: Warning: skipping extended tests for P-192 tests from point-at-infinity.org
#   tv_pai = load_test_vectors(("PublicKey", "ECC"),
# /usr/local/lib/python3.12/dist-packages/Cryptodome/SelfTest/PublicKey/test_ECC_NIST.py:800: UserWarning: Warning: skipping extended tests for P-224 tests from point-at-infinity.org
#   tv_pai = load_test_vectors(("PublicKey", "ECC"),
# /usr/local/lib/python3.12/dist-packages/Cryptodome/SelfTest/PublicKey/test_ECC_NIST.py:821: UserWarning: Warning: skipping extended tests for P-256 tests from point-at-infinity.org
#   tv_pai = load_test_vectors(("PublicKey", "ECC"),
# /usr/local/lib/python3.12/dist-packages/Cryptodome/SelfTest/PublicKey/test_ECC_NIST.py:842: UserWarning: Warning: skipping extended tests for P-384 tests from point-at-infinity.org
# ...

# %% [markdown]
# ## Set Kaggle API creds (fill below or use Colab Secrets)

# %%
import os
# os.environ['KAGGLE_USERNAME'] = os.getenv('KAGGLE_USERNAME','YOUR_KAGGLE_USERNAME')
# os.environ['KAGGLE_KEY'] = os.getenv('KAGGLE_KEY','YOUR_KAGGLE_KEY')
# !python /content/drive/MyDrive/Colab\ Notebooks/Repositories/jd_moppr/scripts/train_colab.py  --data_root "/content/drive/MyDrive/Colab Notebooks/Datasets/jd_search" --kaggle_download 0 --epochs 1 --batch_size 16 --negatives 500  --limit_queries 2000 --artifact_dir /content/artifacts
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/Repositories/jd_moppr/scripts/train_colab.py", line 40, in <module>
#     from jd_moppr.src.jd_moppr.train import train_loop
# ModuleNotFoundError: No module named 'jd_moppr'

# %% [markdown]
# Check `/content/artifacts` for `moppr.pt` and `vocabs.json`.
# Increase `--limit_queries`, `--negatives`, `--epochs` for stronger results.
